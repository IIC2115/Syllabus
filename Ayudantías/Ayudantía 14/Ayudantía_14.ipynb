# %% [markdown]
# # Ayudantía 14: Laboratorio 7 Parte 1 #
# Juan Pablo Tapia | jp.tapia@uc.cl
#
# 26 de Junio, 2025.

# %% [markdown]
# ## Importar librerias

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sqlite3
from IPython.display import display

# %% [markdown]
# ## a) Exploración inicial de los datos

# %%
# !unzip store.zip
# Out:
# Archive:  store.zip
#   inflating: brands.csv
#   inflating: categories.csv
#   inflating: customers.csv
#   inflating: order_items.csv
#   inflating: orders.csv
#   inflating: products.csv
#   inflating: staffs.csv
#   inflating: stocks.csv
#   inflating: stores.csv

# %%
brands = pd.read_csv('brands.csv')
print(f"Brands: {brands.shape[0]}")
brands.info()
display(brands.head())
# Out:
# Brands: 9
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   brand_id    9 non-null      int64
#  1   brand_name  9 non-null      object
# dtypes: int64(1), object(1)
# memory usage: 276.0+ bytes
#    brand_id   brand_name
# 0         1      Electra
# 1         2         Haro
# 2         3       Heller
# 3         4  Pure Cycles
# 4         5      Ritchey

# %% [markdown]
# Las columnas de brands.csv representan el id asociado a una marca y su nombre.
#
# **Llave primaria (PK):**
#
# * brand_id

# %%
categories = pd.read_csv('categories.csv')
print(f"Categories: {categories.shape[0]}")
categories.info()
display(categories.head())
# Out:
# Categories: 7
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   category_id    7 non-null      int64
#  1   category_name  7 non-null      object
# dtypes: int64(1), object(1)
# memory usage: 244.0+ bytes
#    category_id        category_name
# 0            1    Children Bicycles
# 1            2     Comfort Bicycles
# 2            3    Cruisers Bicycles
# 3            4  Cyclocross Bicycles
# 4            5       Electric Bikes

# %% [markdown]
# Las columnas de categories.csv representan el id asociado a una categoria y el nombre de su respectiva categoria.
#
# **Llave primaria (PK):**
#
# * category_id

# %%
customers = pd.read_csv('customers.csv')
print(f"Customers: {customers.shape[0]}")
customers.info()
display(customers.head())
# Out:
# Customers: 1445
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1445 entries, 0 to 1444
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   customer_id  1445 non-null   int64
#  1   first_name   1445 non-null   object
#  2   last_name    1445 non-null   object
#  3   phone        178 non-null    object
#  4   email        1445 non-null   object
#  5   street       1445 non-null   object
#  6   city         1445 non-null   object
#  7   state        1445 non-null   object
#  8   zip_code     1445 non-null   int64
# dtypes: int64(2), object(7)
# memory usage: 101.7+ KB
#    customer_id  first_name last_name           phone                    email  \
# 0            1       Debra     Burks             NaN    debra.burks@yahoo.com
# 1            2       Kasha      Todd             NaN     kasha.todd@yahoo.com
# 2            3      Tameka    Fisher             NaN    tameka.fisher@aol.com
# ...

# %% [markdown]
# Las columnas de customers.csv representan el id asociado a un cliente, su nombre y apellido, el número de telefono, su email, la calle de su dirección, la ciudad y estado en el que vive, y el codigo postal.
#
# **Llave primaria (PK):**
#
# * customer_id

# %%
order_items = pd.read_csv('order_items.csv')
print(f"Order items: {order_items.shape[0]}")
order_items.info()
display(order_items.head())
# Out:
# Order items: 4722
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4722 entries, 0 to 4721
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   order_id    4722 non-null   int64
#  1   item_id     4722 non-null   int64
#  2   product_id  4722 non-null   int64
#  3   quantity    4722 non-null   int64
#  4   list_price  4722 non-null   float64
#  5   discount    4722 non-null   float64
# dtypes: float64(2), int64(4)
# memory usage: 221.5 KB
#    order_id  item_id  product_id  quantity  list_price  discount
# 0         1        1          20         1      599.99      0.20
# 1         1        2           8         2     1799.99      0.07
# 2         1        3          10         2     1549.00      0.05
# 3         1        4          16         2      599.99      0.05
# 4         1        5           4         1     2899.99      0.20

# %% [markdown]
# Las columnas de order_items.csv representan el id de una orden, los id de la cantidad de distintos items pedidos en esa orden, el id del producto asociado al item, la cantidad de items pedidos, la lista de precios, y el descuento.
#
# **Llave primaria (PK):**
#
# * item_id
#
# **Llaves foráneas (FK):**
#
# * order_id
#
# * product_id

# %%
orders = pd.read_csv('orders.csv')
print(f"Orders: {orders.shape[0]}")
orders.info()
display(orders.head())
# Out:
# Orders: 1615
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1615 entries, 0 to 1614
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   order_id       1615 non-null   int64
#  1   customer_id    1615 non-null   int64
#  2   order_status   1615 non-null   int64
#  3   order_date     1615 non-null   object
#  4   required_date  1615 non-null   object
#  5   shipped_date   1445 non-null   object
#  6   store_id       1615 non-null   int64
#  7   staff_id       1615 non-null   int64
# dtypes: int64(5), object(3)
# memory usage: 101.1+ KB
#    order_id  customer_id  order_status  order_date required_date shipped_date  \
# 0         1          259             4  2016-01-01    2016-01-03   2016-01-03
# 1         2         1212             4  2016-01-01    2016-01-04   2016-01-03
# 2         3          523             4  2016-01-02    2016-01-05   2016-01-03
# ...

# %% [markdown]
# Las columnas de orders.csv representan el id de una orden, el id del cliente que hizo esa orden, el estatus de la orden, la fecha del pedido, la fecha de cuando se requiere esa orden, la fecha en que se eniva el pedido, el id de la teinda y el id del staff.
#
# **Llave primaria (PK):**
#
# * order_id
#
# **Llaves foráneas (FK):**
#
# * customer_id
#
# * store_id
#
# * staff_id

# %%
products = pd.read_csv('products.csv')
print(f"Products: {products.shape[0]}")
products.info()
display(products.head())
# Out:
# Products: 321
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 321 entries, 0 to 320
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   product_id    321 non-null    int64
#  1   product_name  321 non-null    object
#  2   brand_id      321 non-null    int64
#  3   category_id   321 non-null    int64
#  4   model_year    321 non-null    int64
#  5   list_price    321 non-null    float64
# dtypes: float64(1), int64(4), object(1)
# memory usage: 15.2+ KB
#    product_id                        product_name  brand_id  category_id  \
# 0           1                     Trek 820 - 2016         9            6
# 1           2  Ritchey Timberwolf Frameset - 2016         5            6
# 2           3     Surly Wednesday Frameset - 2016         8            6
# 3           4            Trek Fuel EX 8 29 - 2016         9            6
# 4           5        Heller Shagamaw Frame - 2016         3            6
#
# ...

# %% [markdown]
# Las columnas de products.csv representan el id del producto, su nombre, el id de la marca, el id de la categoria, el año del modelo y su precio.
#
# **Llave primaria (PK):**
#
# * product_id
#
# **Llaves foráneas (FK):**
#
# * brand_id
#
# * category_id

# %%
staffs = pd.read_csv('staffs.csv')
print(f"Staffs: {staffs.shape[0]}")
staffs.info()
display(staffs.head())
# Out:
# Staffs: 10
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   staff_id    10 non-null     int64
#  1   first_name  10 non-null     object
#  2   last_name   10 non-null     object
#  3   email       10 non-null     object
#  4   phone       10 non-null     object
#  5   active      10 non-null     int64
#  6   store_id    10 non-null     int64
#  7   manager_id  9 non-null      float64
# dtypes: float64(1), int64(3), object(4)
# memory usage: 772.0+ bytes
#    staff_id first_name last_name                       email           phone  \
# 0         1    Fabiola   Jackson  fabiola.jackson@bikes.shop  (831) 555-5554
# 1         2     Mireya  Copeland  mireya.copeland@bikes.shop  (831) 555-5555
# 2         3      Genna   Serrano    genna.serrano@bikes.shop  (831) 555-5556
# ...

# %% [markdown]
# Las columnas de staffs.csv representan el id del staff, su nombre y apellido, su email, si se encuentra activo, el id de la tienda y el id del gerente.
#
# **Llave primaria (PK):**
#
# * staff_id
#
# **Llaves foráneas (FK):**
#
# * store_id
#
# * manager_id

# %%
stocks = pd.read_csv('stocks.csv')
print(f"Stocks: {stocks.shape[0]}")
stocks.info()
display(stocks.head())
# Out:
# Stocks: 939
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 939 entries, 0 to 938
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   store_id    939 non-null    int64
#  1   product_id  939 non-null    int64
#  2   quantity    939 non-null    int64
# dtypes: int64(3)
# memory usage: 22.1 KB
#    store_id  product_id  quantity
# 0         1           1        27
# 1         1           2         5
# 2         1           3         6
# 3         1           4        23
# 4         1           5        22

# %% [markdown]
# Las columnas de stocks.csv representan el id de la tienda, el id del producto y la cantidad de stock.
#
# **Llave primaria (PK):**
#
# * product_id
#
# **Llaves foráneas (FK):**
#
# *  store_id

# %%
stores = pd.read_csv('stores.csv')
print(f"Stores: {stores.shape[0]}")
stores.info()
display(stores.head())
# Out:
# Stores: 3
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   store_id    3 non-null      int64
#  1   store_name  3 non-null      object
#  2   phone       3 non-null      object
#  3   email       3 non-null      object
#  4   street      3 non-null      object
#  5   city        3 non-null      object
#  6   state       3 non-null      object
#  7   zip_code    3 non-null      int64
# dtypes: int64(2), object(6)
# memory usage: 324.0+ bytes
#    store_id        store_name           phone                 email  \
# 0         1  Santa Cruz Bikes  (831) 476-4321  santacruz@bikes.shop
# 1         2     Baldwin Bikes  (516) 379-8888    baldwin@bikes.shop
# 2         3     Rowlett Bikes  (972) 530-5555    rowlett@bikes.shop
#
#                 street        city state  zip_code
# 0   3700 Portola Drive  Santa Cruz    CA     95060
# ...

# %% [markdown]
# Las columnas de stores.csv representan el id de la tienda, el nombre de la tienda, el telefono, el email, la calle, la ciudad, el estado y el codigo postal.
#
# **Llave primaria (PK):**
#
# * store_id

# %% [markdown]
# ## b) Propuesta de estructura relacional

# %% [markdown]
# . A continuación, se indican las tablas a modelar:
#
# - **Brands**: información de las marcas que maneja la tienda.
# - **Categories**: indica las distintas categorias de los productos vendidos.
# - **Customers**: almacena información de los clientes.
# - **Order_items**: contiene los registros de los items pedidos en una orden.
# - **Orders**: información sobre las ordenes realizadas.
# - **Products**: otorga la información sobre los productos que vende la tienda.
# - **Staffs**: almacena los datos del staff de las tiendas.
# - **Stocks**: contiene información sobre el stock que tiene cada una de las tiendas.
# - **Stores**: los distintos locales de la tienda.

# %% [markdown]
# **Brands**
#
# Atributos:
#
# * brand_id (PK)
#
# * brand_name

# %% [markdown]
# **Categories**
#
# Atributos:
#
# * category_id (PK)
#
# * category_name

# %% [markdown]
# **Customers**
#
# Atributos:
#
# * customer_id (PK)
#
# * first_name
#
# * last_name
#
# * phone
#
# * email
#
# * street
#
# * city
#
# * state
#
# * zip_code

# %% [markdown]
# **Order_items**
#
# Atributos:
#
# * item_id (PK)
#
# * order_id (FK → Orders)
#
# * product_id (FK → Products)
#
# * quantity
#
# * list_price
#
# * discount
#
# Relaciones:
#
# * Una orden tiene multiples items (1:N).
#
# * Un item es de solo un tipo de producto (1:1).

# %% [markdown]
# **Orders**
#
# Atributos:
#
# * order_id (PK)
#
# * customer_id (FK → Customers)
#
# * order_status
#
# * order_date
#
# * required_date
#
# * shipped_date
#
# * store_id (FK → Stores)
#
# * staff_id (FK → Staffs)
#
# Relaciones:
#
# * Una orden la realiza un solo cliente (1:1).
#
# * Un staff atiende multiples ordenes (1:N).
#
# * Un tienda realiza multiples ordenes (1:N).

# %% [markdown]
# **Products**
#
# Atributos:
#
# * product_id (PK)
#
# * product_name
#
# * brand_id (FK → Brands)
#
# * category_id (FK → Categories)
#
# * model_year
#
# * list_price
#
# Relaciones:
#
# * Una marca tiene multiples productos (1:N).
#
# * Un categoria tiene multiples productos (1:N).

# %% [markdown]
# **Staffs**
#
# Atributos:
#
# * staff_id (PK)
#
# * first_name
#
# * last_name
#
# * email
#
# * phone
#
# * active
#
# * store_id (FK → Stores)
#
# * manager_id
#
# Relaciones:
#
# * Una tienda tiene multiples empleados (1:N).

# %% [markdown]
# **Stocks**
#
# Atributos:
#
# * store_id (FK → Stores)
#
# * product_id (FK → Products)
#
# * quantity
#
# Relaciones:
#
# * Una tienda tiene multiples productos (1:N).

# %% [markdown]
# **Stores**
#
# Atributos:
#
# * store_id (PK)
#
# * store_name
#
# * phone
#
# * email
#
# * street
#
# * city
#
# * state
#
# * zip_code

# %% [markdown]
# ## c) Implementación del esquema en SQLite

# %%
connection = sqlite3.connect('store.db')
cursor = connection.cursor()

# %% [markdown]
# Crear tabla Brands.

# %%
cursor.execute("""
CREATE TABLE Brands (
    brand_id INTEGER PRIMARY KEY,
    brand_name VARCHAR
)
""")

# %% [markdown]
# Crear tabla Categories.

# %%
cursor.execute("""
CREATE TABLE Categories (
    category_id INTEGER PRIMARY KEY,
    category_name VARCHAR
)
""")

# %% [markdown]
# Crear tabla Customers.

# %%
cursor.execute("""
CREATE TABLE Customers (
    customer_id INTEGER PRIMARY KEY,
    first_name VARCHAR,
    last_name VARCHAR,
    phone VARCHAR,
    email VARCHAR,
    street VARCHAR,
    city VARCHAR,
    state VARCHAR,
    zip_code VARCHAR
)
""")

# %% [markdown]
# Crear tabla Order_items.

# %%
cursor.execute("""
CREATE TABLE Order_items (
    item_id INTEGER,
    order_id INTEGER,
    product_id INTEGER,
    quantity INTEGER,
    list_price REAL,
    discount REAL,
    FOREIGN KEY (order_id) REFERENCES Orders(order_id),
    FOREIGN KEY (product_id) REFERENCES Products(product_id)
)
""")

# %% [markdown]
# Crear tabla Orders.

# %%
cursor.execute("""
CREATE TABLE Orders (
    order_id INTEGER PRIMARY KEY,
    customer_id INTEGER,
    order_status VARCHAR,
    order_date VARCHAR,
    required_date VARCHAR,
    shipped_date VARCHAR,
    store_id INTEGER,
    staff_id INTEGER,
    FOREIGN KEY (customer_id) REFERENCES Customers(customer_id),
    FOREIGN KEY (store_id) REFERENCES Stores(store_id),
    FOREIGN KEY (staff_id) REFERENCES Staffs(staff_id)
)
""")

# %% [markdown]
# Crear tabla Products.

# %%
cursor.execute("""
CREATE TABLE Products (
    product_id INTEGER PRIMARY KEY,
    product_name VARCHAR,
    brand_id INTEGER,
    category_id INTEGER,
    model_year INTEGER,
    list_price REAL,
    FOREIGN KEY (brand_id) REFERENCES Brands(brand_id),
    FOREIGN KEY (category_id) REFERENCES Categories(category_id)
)
""")

# %% [markdown]
# Crear tabla Staffs.

# %%
cursor.execute("""
CREATE TABLE Staffs (
    staff_id INTEGER PRIMARY KEY,
    first_name VARCHAR,
    last_name VARCHAR,
    email VARCHAR,
    phone VARCHAR,
    active INTEGER,
    store_id INTEGER,
    manager_id INTEGER,
    FOREIGN KEY (store_id) REFERENCES Stores(store_id)
)
""")

# %% [markdown]
# Crear tabla Stocks.

# %%
cursor.execute("""
CREATE TABLE Stocks (
    store_id INTEGER,
    product_id INTEGER,
    quantity INTEGER,
    FOREIGN KEY (store_id) REFERENCES Stores(store_id),
    FOREIGN KEY (product_id) REFERENCES Products(product_id)
)
""")

# %% [markdown]
# Crear tabla Stores.

# %%
cursor.execute("""
CREATE TABLE Stores (
    store_id INTEGER PRIMARY KEY,
    store_name VARCHAR,
    phone VARCHAR,
    email VARCHAR,
    street VARCHAR,
    city VARCHAR,
    state VARCHAR,
    zip_code VARCHAR
)
""")

# %% [markdown]
# Hacer commit de los cambios

# %%
connection.commit()

# %% [markdown]
# ## d) Carga de datos y verificación

# %% [markdown]
# Cargar datos en Brands.

# %%
brands.to_sql('Brands', connection, if_exists='append', index=False)
cursor.execute("SELECT COUNT(*) FROM Brands")
count_brands = cursor.fetchone()[0]
print(f"Cantidad de registros en la tabla Brands: {count_brands}")
# Out:
# Cantidad de registros en la tabla Brands: 9

# %% [markdown]
# Cargar datos en Categories.

# %%
categories.to_sql('Categories', connection, if_exists='append', index=False)
cursor.execute("SELECT COUNT(*) FROM Categories")
count_categories = cursor.fetchone()[0]
print(f"Cantidad de registros en la tabla Categories: {count_categories}")
# Out:
# Cantidad de registros en la tabla Categories: 7

# %% [markdown]
# Cargar datos en Customers.

# %%
customers.to_sql('Customers', connection, if_exists='append', index=False)
cursor.execute("SELECT COUNT(*) FROM Customers")
count_customers = cursor.fetchone()[0]
print(f"Cantidad de registros en la tabla Customers: {count_customers}")
# Out:
# Cantidad de registros en la tabla Customers: 1445

# %% [markdown]
# Cargar datos en Order_items.

# %%
order_items.to_sql('Order_items', connection, if_exists='append', index=False)
cursor.execute("SELECT COUNT(*) FROM Order_items")
count_order_items = cursor.fetchone()[0]
print(f"Cantidad de registros en la tabla Order_items: {count_order_items}")
# Out:
# Cantidad de registros en la tabla Order_items: 4722

# %% [markdown]
# Cargar datos en Orders.

# %%
orders.to_sql('Orders', connection, if_exists='append', index=False)
cursor.execute("SELECT COUNT(*) FROM Orders")
count_orders = cursor.fetchone()[0]
print(f"Cantidad de registros en la tabla Orders: {count_orders}")
# Out:
# Cantidad de registros en la tabla Orders: 1615

# %% [markdown]
# Cargar datos en Products.

# %%
products.to_sql('Products', connection, if_exists='append', index=False)
cursor.execute("SELECT COUNT(*) FROM Products")
count_products = cursor.fetchone()[0]
print(f"Cantidad de registros en la tabla Products: {count_products}")
# Out:
# Cantidad de registros en la tabla Products: 321

# %% [markdown]
# Cargar datos en Staffs.

# %%
staffs.to_sql('Staffs', connection, if_exists='append', index=False)
cursor.execute("SELECT COUNT(*) FROM Staffs")
count_staffs = cursor.fetchone()[0]
print(f"Cantidad de registros en la tabla Staffs: {count_staffs}")
# Out:
# Cantidad de registros en la tabla Staffs: 10

# %% [markdown]
# Cargar datos en Stocks.

# %%
stocks.to_sql('Stocks', connection, if_exists='append', index=False)
cursor.execute("SELECT COUNT(*) FROM Stocks")
count_stocks = cursor.fetchone()[0]
print(f"Cantidad de registros en la tabla Stocks: {count_stocks}")
# Out:
# Cantidad de registros en la tabla Stocks: 939

# %% [markdown]
# Cargar datos en Stores.

# %%
stores.to_sql('Stores', connection, if_exists='append', index=False)
cursor.execute("SELECT COUNT(*) FROM Stores")
count_stores = cursor.fetchone()[0]
print(f"Cantidad de registros en la tabla Stores: {count_stores}")
# Out:
# Cantidad de registros en la tabla Stores: 3

# %% [markdown]
# Hacer commit de los cambios.

# %%
connection.commit()

# %% [markdown]
# Cerrar conexión.

# %%
connection.close()
