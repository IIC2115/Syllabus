# %% [markdown]
# # Ayudantía 11: Extracción y visualización de datos #
# Juan Pablo Tapia | jp.tapia@uc.cl
#
# 05 de Junio, 2025.

# %% [markdown]
# ## Importar librerias

# %%
# !pip install dash dash-bootstrap-components requests
# Out:
# Requirement already satisfied: dash in /usr/local/lib/python3.11/dist-packages (3.0.4)
# Requirement already satisfied: dash-bootstrap-components in /usr/local/lib/python3.11/dist-packages (2.0.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (2.32.3)
# Requirement already satisfied: Flask<3.1,>=1.0.4 in /usr/local/lib/python3.11/dist-packages (from dash) (3.0.3)
# Requirement already satisfied: Werkzeug<3.1 in /usr/local/lib/python3.11/dist-packages (from dash) (3.0.6)
# Requirement already satisfied: plotly>=5.0.0 in /usr/local/lib/python3.11/dist-packages (from dash) (5.24.1)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.11/dist-packages (from dash) (8.7.0)
# Requirement already satisfied: typing-extensions>=4.1.1 in /usr/local/lib/python3.11/dist-packages (from dash) (4.13.2)
# Requirement already satisfied: retrying in /usr/local/lib/python3.11/dist-packages (from dash) (1.3.4)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.11/dist-packages (from dash) (1.6.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from dash) (75.2.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests) (2025.4.26)
# Requirement already satisfied: Jinja2>=3.1.2 in /usr/local/lib/python3.11/dist-packages (from Flask<3.1,>=1.0.4->dash) (3.1.6)
# Requirement already satisfied: itsdangerous>=2.1.2 in /usr/local/lib/python3.11/dist-packages (from Flask<3.1,>=1.0.4->dash) (2.2.0)
# Requirement already satisfied: click>=8.1.3 in /usr/local/lib/python3.11/dist-packages (from Flask<3.1,>=1.0.4->dash) (8.2.1)
# Requirement already satisfied: blinker>=1.6.2 in /usr/local/lib/python3.11/dist-packages (from Flask<3.1,>=1.0.4->dash) (1.9.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from plotly>=5.0.0->dash) (9.1.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from plotly>=5.0.0->dash) (24.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from Werkzeug<3.1->dash) (3.0.2)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.11/dist-packages (from importlib-metadata->dash) (3.22.0)
# Requirement already satisfied: six>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from retrying->dash) (1.17.0)

# %%
import requests
import pandas as pd
import os
from getpass import getpass
from IPython.display import display
from dash import Dash, html, dcc, Input, Output, State
import dash_bootstrap_components as dbc
import plotly.express as px

# %% [markdown]
# ## Ejercicio Formativo 1 Capítulo 6

# %% [markdown]
# ### Misión 1

# %% [markdown]
# Crear funcion para obtener información de la API.

# %%
def get_weather(ciudad, api_key):
    params = {
        "q": ciudad,
        "appid": api_key,
        "units": "metric",
        "lang": "es"
    }
    url = f"https://api.openweathermap.org/data/2.5/weather?q={ciudad}&appid={api_key}&units=metric&lang=es"
    try:
        response = requests.get(url, params=params)
        data = response.json()

        if response.status_code != 200:
            print(f"Error al consultar {ciudad}: {data.get('message')}")
            return None

        weather_info = {
            "Ciudad": ciudad,
            "Temperatura": data["main"]["temp"],
            "Sensación": data["main"]["feels_like"],
            "Clima": data["weather"][0]["description"],
            "Humedad": data["main"]["humidity"],
            "Viento": data["wind"]["speed"]
        }
        return weather_info

    except Exception as e:
        print(f"Error al obtener datos para {ciudad}: {e}")
        return None

# %% [markdown]
# Función para crear DataFrame de la información obtenida.

# %%
def get_weather_multi(ciudades, api_key):
    datos = []
    for ciudad in ciudades:
        info = get_weather(ciudad, api_key)
        if info:
            datos.append(info)
    return pd.DataFrame(datos)

# %% [markdown]
# Mostrar resultados.

# %%
api_key = "dbfce31aacfcfd1bc0dc71d647a95c8a"
ciudades = ["Santiago", "Buenos Aires", "Lima", "Madrid", "Ciudad de México"]
df_clima = get_weather_multi(ciudades, api_key)
df_clima
# Out:
#              Ciudad  Temperatura  Sensación            Clima  Humedad  Viento
# 0          Santiago        12.97      12.28      cielo claro       75    0.65
# 1      Buenos Aires        13.50      13.28            nubes       91    3.58
# 2              Lima        17.17      17.21            nubes       87    5.14
# 3            Madrid        17.14      16.45      cielo claro       59    2.06
# 4  Ciudad de México        21.64      21.06  nubes dispersas       46    5.14

# %% [markdown]
# ### Misión 2

# %% [markdown]
# Cargar los datasets `df_countries` y `df_cities`.

# %%
df_countries = pd.read_csv("countries.csv")
df_cities = pd.read_csv("cities.csv")
print("Paises:")
display(df_countries.head())
print("\nCiudades:")
display(df_cities.head())
# Out:
# Paises:
#           country     native_name iso2 iso3  population       area    capital  \
# 0     Afghanistan       افغانستان   AF  AFG  26023100.0   652230.0      Kabul
# 1         Albania       Shqipëria   AL  ALB   2895947.0    28748.0     Tirana
# 2         Algeria         الجزائر   DZ  DZA  38700000.0  2381741.0    Algiers
# 3  American Samoa  American Samoa   AS  ASM     55519.0      199.0  Pago Pago
# 4          Angola          Angola   AO  AGO  24383301.0  1246700.0     Luanda
#
#    capital_lat  capital_lng                     region continent
# 0    34.526011    69.177684  Southern and Central Asia      Asia
# 1    41.326873    19.818791            Southern Europe    Europe
# 2    36.775361     3.060188            Northern Africa    Africa
# 3   -14.275479  -170.704830                  Polynesia   Oceania
# 4    -8.827270    13.243951             Central Africa    Africa
# Ciudades:
#   station_id   city_name      country       state iso2 iso3   latitude  \
# 0      41515    Asadabad  Afghanistan       Kunar   AF  AFG  34.866000
# 1      38954    Fayzabad  Afghanistan  Badakhshan   AF  AFG  37.129761
# 2      41560   Jalalabad  Afghanistan   Nangarhar   AF  AFG  34.441527
# 3      38947      Kunduz  Afghanistan      Kunduz   AF  AFG  36.727951
# 4      38987  Qala i Naw  Afghanistan     Badghis   AF  AFG  34.983000
#
#    longitude
# 0  71.150005
# 1  70.579247
# 2  70.436103
# 3  68.872530
# 4  63.133300

# %% [markdown]
# Seleccionar al menos 10 ciudades de 5 países distintos.

# %% [markdown]
# Ciudades de Sudamérica:

# %%
df_countries[df_countries['continent'] == "South America"].sample(5)
# Out:
#        country native_name iso2 iso3   population       area     capital  \
# 145   Paraguay    Paraguay   PY  PRY    6893727.0   406752.0    Asunción
# 203    Uruguay     Uruguay   UY  URY    3404189.0   181034.0  Montevideo
# 24      Brazil      Brasil   BR  BRA  203586000.0  8515767.0    Brasília
# 206  Venezuela   Venezuela   VE  VEN   30206307.0   916445.0     Caracas
# 36       Chile       Chile   CL  CHL   17819054.0   756102.0    Santiago
#
#      capital_lat  capital_lng         region      continent
# 145   -25.280046   -57.634381  South America  South America
# 203   -34.905904   -56.191357  South America  South America
# 24    -10.333333   -53.200000  South America  South America
# 206    10.506098   -66.914602  South America  South America
# 36      9.869479   -83.798075  South America  South America

# %% [markdown]
# Ciudades de Africa:

# %%
df_countries[df_countries['continent'] == "Africa"].sample(5)
# Out:
#           country   native_name iso2 iso3  population       area      capital  \
# 156       Réunion    La Réunion   RE  REU    840974.0        NaN  Saint-Denis
# 35           Chad         Tchad   TD  TCD  13211000.0  1284000.0    N'Djamena
# 28        Burundi       Burundi   BI  BDI   9530434.0    27834.0    Bujumbura
# 107       Liberia       Liberia   LR  LBR   4397000.0   111369.0     Monrovia
# 27   Burkina Faso  Burkina Faso   BF  BFA  17322796.0   272967.0  Ouagadougou
#
#      capital_lat  capital_lng          region continent
# 156    48.935773     2.358023  Eastern Africa    Africa
# 35     12.119154    15.050276  Central Africa    Africa
# 28     -3.363812    29.367503  Eastern Africa    Africa
# 107     6.328034   -10.797788  Western Africa    Africa
# 27     12.368187    -1.527094  Western Africa    Africa

# %% [markdown]
# Ciudades de Asia:

# %%
df_countries[df_countries['continent'] == "Asia"].sample(5)
# Out:
#         country native_name iso2 iso3   population      area    capital  \
# 112       Macau          澳門   MO  MAC     631000.0      30.0        NaN
# 143    Pakistan    Pakistan   PK  PAK  188410000.0  881912.0  Islamabad
# 12   Azerbaijan  Azərbaycan   AZ  AZE    9552500.0   86600.0       Baku
# 189    Thailand   ประเทศไทย   TH  THA   64871000.0  513120.0    Bangkok
# 8       Armenia    Հայաստան   AM  ARM    3009800.0   29743.0    Yerevan
#
#      capital_lat  capital_lng                     region continent
# 112          NaN          NaN               Eastern Asia      Asia
# 143    33.693812    73.065151  Southern and Central Asia      Asia
# 12     40.375443    49.832675                Middle East      Asia
# 189    13.754253   100.493087             Southeast Asia      Asia
# 8      40.177612    44.512585                Middle East      Asia

# %% [markdown]
# Ciudades de Europa:

# %%
df_countries[df_countries['continent'] == "Europe"].sample(5)
# Out:
#         country native_name iso2 iso3  population       area  \
# 84      Iceland      Ísland   IS  ISL    328170.0  103000.00
# 161  San Marino  San Marino   SM  SMR     32743.0      61.00
# 148      Poland      Polska   PL  POL  38496000.0  312679.00
# 71       Greece      Ελλάδα   GR  GRC         NaN  131990.00
# 126      Monaco      Monaco   MC  MCO     36950.0       2.02
#
#                 capital  capital_lat  capital_lng            region continent
# 84            Reykjavik    64.145981   -21.942237  Nordic Countries    Europe
# 161  City of San Marino    43.936400    12.446699   Southern Europe    Europe
# 148              Warsaw    52.233717    21.071411    Eastern Europe    Europe
# 71               Athens    37.983941    23.728305   Southern Europe    Europe
# 126              Monaco    43.732349     7.427683    Western Europe    Europe

# %% [markdown]
# Ciudades de Oceania:

# %%
df_countries[df_countries['continent'] == "Oceania"].sample(5)
# Out:
#               country       native_name iso2 iso3  population      area  \
# 120  Marshall Islands            M̧ajeļ   MH  MHL     56086.0     181.0
# 60               Fiji              Fiji   FJ  FJI    859178.0   18272.0
# 41       Cook Islands      Cook Islands   CK  COK     14974.0     236.0
# 134       New Zealand       New Zealand   NZ  NZL   4547900.0  270467.0
# 38   Christmas Island  Christmas Island   CX  CXR      2072.0     135.0
#
#               capital  capital_lat  capital_lng                     region  \
# 120            Majuro     7.090992   171.381635                 Micronesia
# 60               Suva   -18.141588   178.442166                  Melanesia
# 41             Avarua   -21.207474  -159.770814                  Polynesia
# 134        Wellington   -41.288795   174.777211  Australia and New Zealand
# 38   Flying Fish Cove   -10.426665   105.668672  Australia and New Zealand
#
#     continent
# 120   Oceania
# 60    Oceania
# 41    Oceania
# 134   Oceania
# 38    Oceania

# %%
ciudades_seleccionadas = [
    ("Santiago", "Chile"),
    ("Buenos Aires", "Argentina"),
    ("Nairobi", "South Africa"),
    ("Madrid", "Kenya"),
    ("Doha", "Qatar"),
    ("Tokyo", "Japón"),
    ("London", "United Kingdom"),
    ("Berlin", "Germany"),
    ("Canberra", "Australia"),
    ("Suva", "Fiji")
]

# %% [markdown]
# Obtener el clima actual.

# %%
nombres_ciudades = [c[0] for c in ciudades_seleccionadas]
df_clima = get_weather_multi(nombres_ciudades, api_key)

# %% [markdown]
# Añadir columna de país y calcular la diferencia térmica.

# %%
df_clima["País"] = [c[1] for c in ciudades_seleccionadas]
df_clima["Diferencia"] = abs(df_clima["Temperatura"] - df_clima["Sensación"])

# %% [markdown]
# Reordenar las columnas y ordenar el DataFrame.

# %%
columnas_ordenadas = [
    "Ciudad", "País", "Temperatura", "Sensación", "Diferencia",
    "Clima", "Humedad", "Viento"
]

df_clima = df_clima[columnas_ordenadas].sort_values(by="Diferencia", ascending=False)

# %% [markdown]
# Mostrar los resultados.

# %%
df_clima
# Out:
#          Ciudad            País  Temperatura  Sensación  Diferencia  \
# 9          Suva            Fiji        27.71      32.69        4.98
# 8      Canberra       Australia        11.11       9.56        1.55
# 4          Doha           Qatar        31.99      30.69        1.30
# 0      Santiago           Chile        12.97      12.28        0.69
# 3        Madrid           Kenya        17.14      16.45        0.69
# 6        London  United Kingdom        12.40      11.92        0.48
# 1  Buenos Aires       Argentina        13.50      13.28        0.22
# 5         Tokyo           Japón        27.09      27.20        0.11
# 7        Berlin         Germany        16.68      16.78        0.10
# 2       Nairobi    South Africa        15.62      15.69        0.07
#
#            Clima  Humedad  Viento
# 9  lluvia ligera       89    4.12
# 8    cielo claro       49    1.54
# 4    cielo claro       29    8.23
# 0    cielo claro       75    0.65
# 3    cielo claro       59    2.06
# 6          nubes       85    4.12
# 1          nubes       91    3.58
# 5  algo de nubes       45    5.66
# 7     muy nuboso       91    3.09
# 2     muy nuboso       94    1.03

# %% [markdown]
# Observamos que la mayor diferencia entre temperatura real y sensación térmica se da en **Canberra, Australia**. Esto podría deberse a factores como el viento o la humedad relativa. Ciudades con climas secos tienden a tener menor diferencia. También notamos que varias ciudades tienen sensación más baja que la temperatura real, lo cual es común en ambientes ventosos.

# %% [markdown]
# ### Misión 3

# %% [markdown]
# Renombrar columnas y cruzar datos.

# %%
df_countries_renombrada = df_countries.rename(columns={"country": "País"})
df_clima_merge = df_clima.merge(
    df_countries_renombrada[["País", "population", "area", "continent", "region"]],
    on="País",
    how="left"
)
df_clima_merge
# Out:
#          Ciudad            País  Temperatura  Sensación  Diferencia  \
# 0          Suva            Fiji        27.71      32.69        4.98
# 1      Canberra       Australia        11.11       9.56        1.55
# 2          Doha           Qatar        31.99      30.69        1.30
# 3      Santiago           Chile        12.97      12.28        0.69
# 4        Madrid           Kenya        17.14      16.45        0.69
# 5        London  United Kingdom        12.40      11.92        0.48
# 6  Buenos Aires       Argentina        13.50      13.28        0.22
# 7         Tokyo           Japón        27.09      27.20        0.11
# 8        Berlin         Germany        16.68      16.78        0.10
# 9       Nairobi    South Africa        15.62      15.69        0.07
#
#            Clima  Humedad  Viento  population       area      continent  \
# 0  lluvia ligera       89    4.12    859178.0    18272.0        Oceania
# 1    cielo claro       49    1.54         NaN  7692024.0        Oceania
# 2    cielo claro       29    8.23   2269672.0    11586.0           Asia
# 3    cielo claro       75    0.65  17819054.0   756102.0  South America
# 4    cielo claro       59    2.06  41800000.0   580367.0         Africa
# 5          nubes       85    4.12  64105654.0   242900.0         Europe
# 6          nubes       91    3.58  42669500.0  2780400.0  South America
# 7  algo de nubes       45    5.66         NaN        NaN            NaN
# 8     muy nuboso       91    3.09  80783000.0   357114.0         Europe
# 9     muy nuboso       94    1.03  54002000.0  1221037.0         Africa
#
#                       region
# 0                  Melanesia
# 1  Australia and New Zealand
# 2                Middle East
# 3              South America
# 4             Eastern Africa
# 5              British Isles
# 6              South America
# 7                        NaN
# 8             Western Europe
# 9            Southern Africa

# %% [markdown]
# Agrupar por continente y analizar.

# %%
resumen_continente = df_clima_merge.groupby("continent").agg({
    "Temperatura": "mean",
    "Sensación": "mean",
    "Diferencia": "mean",
    "Humedad": "mean",
    "Viento": "mean"
}).round(2).reset_index()

resumen_continente
# Out:
#        continent  Temperatura  Sensación  Diferencia  Humedad  Viento
# 0         Africa        16.38      16.07        0.38     76.5    1.54
# 1           Asia        31.99      30.69        1.30     29.0    8.23
# 2         Europe        14.54      14.35        0.29     88.0    3.60
# 3        Oceania        19.41      21.12        3.26     69.0    2.83
# 4  South America        13.24      12.78        0.46     83.0    2.12

# %% [markdown]
# Al agrupar por continente, se observa que las condiciones climáticas varían bastante entre regiones. Por ejemplo, **América del Sur** muestra temperaturas más bajas en promedio, mientras que **Asia** presenta menor humedad. Las diferencias térmicas mayores se ven en regiones con climas extremos como **Oceanía**. Esta comparación ayuda a entender patrones globales y posibles influencias geográficas.

# %% [markdown]
# ### Misión 4

# %% [markdown]
# Importar la tabla desde Wikipedia.

# %%
url = "https://es.wikipedia.org/wiki/Anexo:R%C3%A9cords_meteorol%C3%B3gicos_mundiales"

tablas = pd.read_html(url)

for i, tabla in enumerate(tablas):
    print(f"Tabla {i}: {tabla.columns}")
    display(tabla.head())
# Out:
# Tabla 0: MultiIndex([('Unnamed: 0_level_0', 'América del Norte[editar]'),
#             (       'Temperatura', 'América del Norte[editar]'),
#             (         'Ubicación', 'América del Norte[editar]'),
#             (             'Fecha', 'América del Norte[editar]')],
#            )
#                    Unnamed: 0_level_0                         Temperatura  \
#             América del Norte[editar]           América del Norte[editar]
# 0                      Estados Unidos                    56,7 °C (134 °F)
# 1                              México                  52,5 °C (126,3 °F)
# 2                              Canadá                  49,6 °C (121,3 °F)
# 3                         Groenlandia                   30,1 °C (86,2 °F)
# 4  América Central y Antillas[editar]  América Central y Antillas[editar]
#
#                             Ubicación                               Fecha
#             América del Norte[editar]           América del Norte[editar]
# 0     Valle de la Muerte (California)                      1913-07-10[8]​
# 1      San Luis Río Colorado (Sonora)                      1966-06-15[9]​
# 2         Lytton (Columbia Británica)                     2021-06-29[10]​
# 3                            Ivittuut                     1915-06-23[11]​
# 4  América Central y Antillas[editar]  América Central y Antillas[editar]
# Tabla 1: Index(['Unnamed: 0', 'Temperatura', 'Ubicación', 'Fecha'], dtype='object')
#            Unnamed: 0           Temperatura  \
# 0           Antártida  –89,2 °C (–128,6 °F)
# 1  Antártida Oriental  −82,5 °C (–116,5 °F)
# 2            Polo sur    –82,8 °C (–117 °F)
# 3                Asia                   NaN
# 4               Rusia       −68 °C (−90 °F)
#
#                                            Ubicación  \
# 0                                        Base Vostok
# 1                                             Dome A
# 2                                Base Amundsen-Scott
# 3                                                NaN
# 4  Verkhoyansk y Oymyakon, ambas en la república ...
#
#                         Fecha
# 0   1983-07-21[18]​[97]​[98]​
# 1                2005-07[99]​
# 2                      [100]​
# 3                         NaN
# 4  1892-02-07 1933-02-06[18]​
# Tabla 2: Index([0, 1], dtype='int64')
#                                               0  \
# 0  Lugar habitado más cálido, temperatura media
# 1    Lugar habitado más frío, temperatura media
#
#                                                    1
# 0  Dallol, Etiopía; la temperatura media anual es...
# 1  Eureka (Nunavut, Canadá); la temperatura media...
# Tabla 3: Index([0, 1], dtype='int64')
#                         0                                    1
# 0  Control de autoridades  Proyectos Wikimedia  Datos: Q492018

# %% [markdown]
# Guardamos tabla de temperaturas.

# %%
df_records = tablas[0].copy()
df_records.columns = df_records.columns.get_level_values(0)
df_records.head()
# Out:
#                    Unnamed: 0_level_0                         Temperatura  \
# 0                      Estados Unidos                    56,7 °C (134 °F)
# 1                              México                  52,5 °C (126,3 °F)
# 2                              Canadá                  49,6 °C (121,3 °F)
# 3                         Groenlandia                   30,1 °C (86,2 °F)
# 4  América Central y Antillas[editar]  América Central y Antillas[editar]
#
#                             Ubicación                               Fecha
# 0     Valle de la Muerte (California)                      1913-07-10[8]​
# 1      San Luis Río Colorado (Sonora)                      1966-06-15[9]​
# 2         Lytton (Columbia Británica)                     2021-06-29[10]​
# 3                            Ivittuut                     1915-06-23[11]​
# 4  América Central y Antillas[editar]  América Central y Antillas[editar]

# %% [markdown]
# Renombrar columnas y ajustar temperatura a float.

# %%
df_records.columns = ["País", "Temperatura", "Lugar", "Fecha"]
df_records["Temperatura"] = (
    df_records["Temperatura"]
    .astype(str)
    .str.extract(r"(\d+,\d+|\d+\.\d+|\d+)")
    .replace(",", ".", regex=True)
    .astype(float)
)
df_records.head()
# Out:
#                                  País  Temperatura  \
# 0                      Estados Unidos         56.7
# 1                              México         52.5
# 2                              Canadá         49.6
# 3                         Groenlandia         30.1
# 4  América Central y Antillas[editar]          NaN
#
#                                 Lugar                               Fecha
# 0     Valle de la Muerte (California)                      1913-07-10[8]​
# 1      San Luis Río Colorado (Sonora)                      1966-06-15[9]​
# 2         Lytton (Columbia Británica)                     2021-06-29[10]​
# 3                            Ivittuut                     1915-06-23[11]​
# 4  América Central y Antillas[editar]  América Central y Antillas[editar]

# %% [markdown]
# Renombrar columnas y cruzar datos.

# %%
df_records_merge = df_records[["País", "Temperatura"]].rename(columns={"Temperatura": "Máxima histórica"})
df_clima_ext = df_clima_merge.merge(df_records_merge, on="País", how="left")

# %% [markdown]
# Verificar valores faltantes.

# %%
faltantes = df_clima_ext[df_clima_ext["Máxima histórica"].isna()]["País"].unique()
print("Países sin datos históricos:", faltantes)
# Out:
# Países sin datos históricos: ['Fiji' 'Qatar' 'Kenya' 'United Kingdom' 'Germany' 'South Africa']

# %% [markdown]
# Comparar temperatura actual con la histórica.

# %%
df_clima_ext["Excede histórica (%)"] = (
    (df_clima_ext["Temperatura"] / df_clima_ext["Máxima histórica"]) * 100
).round(2)
df_clima_ext
# Out:
#          Ciudad            País  Temperatura  Sensación  Diferencia  \
# 0          Suva            Fiji        27.71      32.69        4.98
# 1      Canberra       Australia        11.11       9.56        1.55
# 2          Doha           Qatar        31.99      30.69        1.30
# 3      Santiago           Chile        12.97      12.28        0.69
# 4        Madrid           Kenya        17.14      16.45        0.69
# 5        London  United Kingdom        12.40      11.92        0.48
# 6  Buenos Aires       Argentina        13.50      13.28        0.22
# 7         Tokyo           Japón        27.09      27.20        0.11
# 8        Berlin         Germany        16.68      16.78        0.10
# 9       Nairobi    South Africa        15.62      15.69        0.07
#
#            Clima  Humedad  Viento  population       area      continent  \
# 0  lluvia ligera       89    4.12    859178.0    18272.0        Oceania
# 1    cielo claro       49    1.54         NaN  7692024.0        Oceania
# 2    cielo claro       29    8.23   2269672.0    11586.0           Asia
# 3    cielo claro       75    0.65  17819054.0   756102.0  South America
# 4    cielo claro       59    2.06  41800000.0   580367.0         Africa
# 5          nubes       85    4.12  64105654.0   242900.0         Europe
# 6          nubes       91    3.58  42669500.0  2780400.0  South America
# 7  algo de nubes       45    5.66         NaN        NaN            NaN
# 8     muy nuboso       91    3.09  80783000.0   357114.0         Europe
# 9     muy nuboso       94    1.03  54002000.0  1221037.0         Africa
#
#                       region  Máxima histórica  Excede histórica (%)
# 0                  Melanesia               NaN                   NaN
# 1  Australia and New Zealand              50.7                 21.91
# 2                Middle East               NaN                   NaN
# 3              South America              43.0                 30.16
# 4             Eastern Africa               NaN                   NaN
# 5              British Isles               NaN                   NaN
# 6              South America              49.1                 27.49
# 7                        NaN              40.9                 66.23
# 8             Western Europe               NaN                   NaN
# 9            Southern Africa               NaN                   NaN

# %% [markdown]
#  En esta misión realizamos web scraping de una tabla de Wikipedia con temperaturas máximas históricas por país, y comparamos estos valores con las temperaturas actuales de distintas ciudades. Observamos que la mayoría de las ciudades tienen temperaturas actuales significativamente por debajo del récord histórico de su país. Esto es esperable, ya que los récords suelen ocurrir en condiciones extremas y localizadas, como desiertos o durante olas de calor inusuales.
#
# Algunas dificultades encontradas fueron las diferencias en nombres de países entre fuentes, y la localización específica de las mediciones históricas, que muchas veces no coinciden con las ciudades analizadas.

# %% [markdown]
# ## Ejercicio Formativo 2 Capítulo 6

# %% [markdown]
# ### Misión 1

# %% [markdown]
# Estructura base de la app.

# %%
# Inicializamos la app con estilo Bootstrap
app = Dash(__name__, external_stylesheets=[dbc.themes.BOOTSTRAP])

# Tu API Key de OpenWeatherMap
API_KEY = "dbfce31aacfcfd1bc0dc71d647a95c8a"

# Función para obtener el clima actual
def get_weather(ciudad, api_key):
    url = "https://api.openweathermap.org/data/2.5/weather"
    params = {
        "q": ciudad,
        "appid": api_key,
        "units": "metric",
        "lang": "es"
    }
    try:
        response = requests.get(url, params=params)
        data = response.json()
        if response.status_code != 200:
            return f"Error: {data.get('message')}"

        weather_info = {
            "Ciudad": ciudad,
            "Temperatura": f"{data['main']['temp']} °C",
            "Sensación térmica": f"{data['main']['feels_like']} °C",
            "Clima": data['weather'][0]['description'],
            "Humedad": f"{data['main']['humidity']}%",
            "Viento": f"{data['wind']['speed']} m/s"
        }
        return weather_info
    except Exception as e:
        return f"Error: {e}"

# %% [markdown]
# Layout de la app.

# %%
app.layout = dbc.Container([
    html.H2("Clima actual por ciudad", className="my-3"),

    dbc.Row([
        dbc.Col([
            dcc.Input(id="input-ciudad", type="text", placeholder="Ingresa una ciudad", className="form-control"),
        ], width=6),

        dbc.Col([
            dbc.Button("Consultar", id="btn-clima", color="primary", className="me-2")
        ], width="auto")
    ], className="mb-4"),

    html.Div(id="resultado-clima")
])

# %% [markdown]
# Callback para actualizar la tarjeta con el clima.

# %%
@app.callback(
    Output("resultado-clima", "children"),
    Input("btn-clima", "n_clicks"),
    State("input-ciudad", "value")
)
def actualizar_clima(n_clicks, ciudad):
    if not ciudad:
        return dbc.Alert("Por favor ingresa una ciudad.", color="warning")

    info = get_weather(ciudad, API_KEY)

    if isinstance(info, str):
        return dbc.Alert(info, color="danger")

    return dbc.Card([
        dbc.CardHeader(html.H5(f"Clima en {info['Ciudad']}")),
        dbc.CardBody([
            html.P(f"Temperatura: {info['Temperatura']}"),
            html.P(f"Sensación térmica: {info['Sensación térmica']}"),
            html.P(f"Clima: {info['Clima']}"),
            html.P(f"Humedad: {info['Humedad']}"),
            html.P(f"Viento: {info['Viento']}")
        ])
    ], color="light", className="mb-3")

# %% [markdown]
#  Ejecutar la aplicación.

# %%
if __name__ == "__main__":
    app.run(debug=True)

# %% [markdown]
# ### Misión 2

# %% [markdown]
# Modificamos el layout.

# %%
# API Key
API_KEY = "dbfce31aacfcfd1bc0dc71d647a95c8a"

# Lista de ciudades sugeridas
ciudades_disponibles = [
    "Santiago", "Buenos Aires", "Lima", "Madrid", "Ciudad de México",
    "Paris", "Tokyo", "Cairo", "New York", "Sydney"
]

app = Dash(__name__, external_stylesheets=[dbc.themes.BOOTSTRAP])

# Función para obtener info del clima
def get_weather(ciudad, api_key):
    url = "https://api.openweathermap.org/data/2.5/weather"
    params = {
        "q": ciudad,
        "appid": api_key,
        "units": "metric",
        "lang": "es"
    }
    try:
        r = requests.get(url, params=params)
        data = r.json()
        if r.status_code != 200:
            return None

        return {
            "Ciudad": ciudad,
            "Temperatura": data["main"]["temp"],
            "Sensación térmica": data["main"]["feels_like"],
            "Clima": data["weather"][0]["description"],
            "Humedad": data["main"]["humidity"],
            "Viento": data["wind"]["speed"]
        }
    except:
        return None

app.layout = dbc.Container([
    html.H2("Comparación de clima en múltiples ciudades", className="my-3"),

    dcc.Dropdown(
        id="dropdown-ciudades",
        options=[{"label": c, "value": c} for c in ciudades_disponibles],
        multi=True,
        placeholder="Selecciona ciudades"
    ),

    dbc.Button("Consultar clima", id="btn-multi", color="primary", className="mt-3"),

    html.Div(id="tarjetas-clima", className="mt-4"),
    dcc.Graph(id="grafico-temperaturas", className="mt-4")
])

# %% [markdown]
# Crear callback para tarjetas y gráfico.

# %%
@app.callback(
    [Output("tarjetas-clima", "children"),
     Output("grafico-temperaturas", "figure")],
    Input("btn-multi", "n_clicks"),
    Input("dropdown-ciudades", "value")
)
def actualizar_ciudades(n_clicks, ciudades):
    if not ciudades:
        return dbc.Alert("Selecciona al menos una ciudad.", color="warning"), {}

    datos = []
    tarjetas = []

    for ciudad in ciudades:
        info = get_weather(ciudad, API_KEY)
        if info:
            datos.append(info)

            tarjetas.append(
                dbc.Card([
                    dbc.CardHeader(html.H5(f"{info['Ciudad']}")),
                    dbc.CardBody([
                        html.P(f"Temperatura: {info['Temperatura']} °C"),
                        html.P(f"Sensación: {info['Sensación térmica']} °C"),
                        html.P(f"Clima: {info['Clima']}"),
                        html.P(f"Humedad: {info['Humedad']}%"),
                        html.P(f"Viento: {info['Viento']} m/s"),
                    ])
                ], color="light", className="mb-3")
            )

    # Crear gráfico de comparación
    df = pd.DataFrame(datos)
    fig = px.bar(df, x="Ciudad", y="Temperatura", title="Temperatura actual por ciudad", color="Ciudad")

    return tarjetas, fig

# %% [markdown]
#  Ejecutar la app.

# %%
if __name__ == "__main__":
    app.run(debug=True)

# %% [markdown]
# ### Misión 3

# %% [markdown]
# Cargar los datos históricos de temperatura.

# %%
# Web scraping desde Wikipedia
url = "https://es.wikipedia.org/wiki/Anexo:R%C3%A9cords_meteorol%C3%B3gicos_mundiales"
tablas = pd.read_html(url)
df_records = tablas[0].copy()
df_records.columns = df_records.columns.get_level_values(1)
df_records.columns = ["País", "Temperatura", "Lugar", "Fecha"]

# Limpiar columna de temperatura
df_records["Temperatura"] = (
    df_records["Temperatura"]
    .astype(str)
    .str.extract(r"(\d+,\d+|\d+\.\d+|\d+)")
    .replace(",", ".", regex=True)
    .astype(float)
)

# Diccionario de temperaturas históricas por país
dict_hist_temp = df_records.set_index("País")["Temperatura"].to_dict()

# %% [markdown]
# Agregar país a cada ciudad y obtener máxima histórica.

# %%
def get_weather(ciudad, api_key):
    url = "https://api.openweathermap.org/data/2.5/weather"
    params = {
        "q": ciudad,
        "appid": api_key,
        "units": "metric",
        "lang": "es"
    }
    try:
        r = requests.get(url, params=params)
        data = r.json()
        if r.status_code != 200:
            return None

        # Nombre del país (puede requerir un mapeo más preciso si quieres unir con nombres de Wikipedia)
        codigo_pais = data["sys"]["country"]

        return {
            "Ciudad": ciudad,
            "País": codigo_pais,
            "Temperatura": data["main"]["temp"],
            "Sensación térmica": data["main"]["feels_like"],
            "Clima": data["weather"][0]["description"],
            "Humedad": data["main"]["humidity"],
            "Viento": data["wind"]["speed"]
        }
    except:
        return None

# %% [markdown]
# Adaptar el callback para mostrar la diferencia con la histórica.

# %%
@app.callback(
    [Output("tarjetas-clima", "children"),
     Output("grafico-temperaturas", "figure")],
    Input("btn-multi", "n_clicks"),
    Input("dropdown-ciudades", "value")
)
def actualizar_ciudades(n_clicks, ciudades):
    if not ciudades:
        return dbc.Alert("Selecciona al menos una ciudad.", color="warning"), {}

    datos = []
    tarjetas = []

    for ciudad in ciudades:
        info = get_weather(ciudad, API_KEY)
        if info:
            # Intentar obtener la máxima histórica por país (nombre común en Wikipedia)
            nombre_pais = info["País"]  # Código ISO (como 'CL'), puedes mapearlo si prefieres usar nombres
            max_hist = None

            # Mapear ISO a nombre si es necesario. Aquí ejemplo básico:
            mapa_codigos = {"CL": "Chile", "AR": "Argentina", "MX": "México",
                            "ES": "España", "FR": "Francia", "JP": "Japón",
                            "US": "Estados Unidos", "AU": "Australia",
                            "EG": "Egipto", "KE": "Kenia"}
            pais_nombre = mapa_codigos.get(nombre_pais, nombre_pais)

            if pais_nombre in dict_hist_temp:
                max_hist = dict_hist_temp[pais_nombre]
                porcentaje = round((info["Temperatura"] / max_hist) * 100, 1)
            else:
                porcentaje = None

            datos.append({**info, "Máxima histórica": max_hist, "% de récord": porcentaje})

            color = "danger" if porcentaje and porcentaje > 90 else "light"

            tarjetas.append(
                dbc.Card([
                    dbc.CardHeader(html.H5(f"{info['Ciudad']} ({pais_nombre})")),
                    dbc.CardBody([
                        html.P(f"Temperatura: {info['Temperatura']} °C"),
                        html.P(f"Sensación: {info['Sensación térmica']} °C"),
                        html.P(f"Clima: {info['Clima']}"),
                        html.P(f"Humedad: {info['Humedad']}%"),
                        html.P(f"Viento: {info['Viento']} m/s"),
                        html.Hr(),
                        html.P(f"Máxima histórica país: {max_hist} °C" if max_hist else "❔ No hay dato histórico"),
                        html.P(f"% del récord: {porcentaje}%" if porcentaje else "")
                    ])
                ], color=color, className="mb-3")
            )

    df = pd.DataFrame(datos)
    fig = px.bar(df, x="Ciudad", y="Temperatura", color="% de récord",
                 title="Temperatura actual por ciudad vs. récord histórico")

    return tarjetas, fig
